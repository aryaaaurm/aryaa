# %%
from flask import Flask, request, jsonify

app = Flask(__name__)

@app.route("/create-user", methods =["POST"]) #another app route for the post method
# this is  a mtehod the user uses to add data to the db or create a resource we can run get and post in this path
def create_user(): #us used another function create_user for the post method
    #can use if statement if there afre multiple (post) methods
    data = request.get_json() #gives the body of the json file that was requested by the user(user data or input)
    return (data), 201 #returns the result in jsonfied format
# print("yuegfuigeiufgeufh")

if __name__ == "__main__":
    app.run()

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)

users = [{"name":"vicky","roll":1},{"name":"Soni","roll":2}]

@app.route('/users/<int:user_id>', methods=['GET'])
def get_user(user_id):
    user = users.get(user_id)
    if user:
        return user
    else:
        return {'error': 'User not found'}
    
# @app.route('/users', methods=['GET'])

# def get_all_users():
#     return users

@app.route('/users', methods=['POST'])
def create_user():
    data = request.get_json()
    user_id = len(users) + 1
    user = {'id': user_id, 'name': data["name"], 'email': data["email"]}
    users[user_id] = user
    return user

@app.route('/users/<int:user_id>', methods=['PUT'])
def update_user(user_id):
    user = users.get(user_id)
    print(user)
    if user:
        data = request.get_json()
        user['name'] = data['name']
        user['email'] = data['email']
        return user
    else:
        return {'error': 'User not found'}


if __name__ == "__main__":
    app.run()

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)
users = {
    1: {'id': 1, 'name': 'John Doe', 'email': 'johndoe@example.com'},
    2: {'id': 2, 'name': 'Jane Smith', 'email': 'janesmith@example.com'}
}
@app.route('/users', methods=['GET'])

def get_all_users():
    return users

if __name__ == "__main__":
    app.run()

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)
users = {
    1: {'id': 1, 'name': 'John Doe', 'email': 'johndoe@example.com'},
    2: {'id': 2, 'name': 'Jane Smith', 'email': 'janesmith@example.com'}
}
@app.route('/users/<int:user_id>', methods=['PUT'])
def update_user(user_id):
    user = users.get(user_id)
    if user:
        data = request.get_json()
        user['name'] = data['name']
        user['email'] = data['email']
        return user
    else:
        return {'error': 'User not found'}
    @app.route('/users/<int:user_id>', methods=['DELETE'])
def delete_user(user_id):
    user = users.pop(user_id, None)
    if user:
        return {'message': 'User deleted successfully'}
    else:
        return {'error': 'User not found'}

if __name__ == "__main__":
    app.run()

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)
users = {
    1: {'id': 1, 'name': 'John Doe', 'email': 'johndoe@example.com'},
    2: {'id': 2, 'name': 'Jane Smith', 'email': 'janesmith@example.com'}
}
@app.route('/users', methods=['POST'])
def create_user():
    data = request.get_json()
    user_id = len(users) + 1
    user = {'id': user_id, 'name': data['name'], 'email': data['email']}
    users[user_id] = user
    return user
if __name__ == "__main__":
    app.run()

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)
users = {
    1: {'id': 1, 'name': 'John Doe', 'email': 'johndoe@example.com'},
    2: {'id': 2, 'name': 'Jane Smith', 'email': 'janesmith@example.com'}
}
@app.route('/users/<int:user_id>', methods=['DELETE'])
def delete_user(user_id):
    user = users.pop(user_id, None)
    if user:
        return {'message': 'User deleted successfully'}
    else:
        return {'error': 'User not found'}
if __name__ == "__main__":
    app.run()

# %%
import request
import json

# Function to get live stock data for a symbol
def get_stock_data():
    url = "https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&outputsize=full&apikey=demo"
    response = request.get(url)
    
    # Check if the response is successful
    if response.status_code == 200:
        data = response.json()
        last_refreshed = data["Meta Data"]["3. Last Refreshed"]
        price = data["Time Series (5min)"][last_refreshed]["1. open"]
        return price
    else:
        return None

stock_prices = {}
price = get_stock_data()
symbol = "IBM"
if price is not None:
    stock_prices[symbol] = price

print(f"{symbol}: {price}")

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)

users = {
    1: {'id': 1, 'name': 'John Doe', 'email': 'johndoe@example.com'},
    2: {'id': 2, 'name': 'Jane Smith', 'email': 'janesmith@example.com'}
}

@app.route('/users/<int:user_id>', methods=['PUT'])
def update_user(user_id):
    user = users.get(user_id)
    # print(user)
    if user:
        data = request.get_json()
    
        user['name'] = data['name']
        user['email'] = data['email']
        return user
    else:
        return {'error': 'User not found'}


if __name__ == "__main__":
    app.run()

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)

users = [{"name":"vicky","roll":1},{"name":"Soni","roll":2}]

@app.route('/users/<string:name>', methods=['PUT'])
def update_user(name):
    data = request.get_json()
    for i in users:
        if i["name"] == name:
            i['roll'] = data['roll']
    
    return users

if __name__ == "__main__":
    app.run()

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)

users = [{"name":"vicky","roll":1},{"name":"Soni","roll":2}]

@app.route('/users', methods=['POST'])
def update_user():
    data = request.get_json()
    x=data["name"]*data["roll"]  
      #for i in users:
     #   if i['roll'] == data['roll']:
        #    i["name"] = data['name']
    
    return jsonify(x)

if __name__ == "__main__":
    app.run()

# %%
import pymongo
client = pymongo.MongoClient('mongodb+srv://aryaamongodb:1t10jivwey6PTTsu@cluster0.mic7q.mongodb.net/')
x = client["practice"]
y = x["pr"]
t = y.find()
print(t)
# Out:
# <pymongo.synchronous.cursor.Cursor object at 0x00000146D563EE40>

# %%
import pymongo
from pymongo.mongo_client import MongoClient
client = MongoClient("mongodb+srv://aryaamongodb:1t10jivwey6PTTsu@cluster0.mic7q.mongodb.net/")
x = client["practice"]
y = x["pr"]
document={
     "name":"aryaa",
     "roll":1}
document2 ={
     "name":"vicky",
     "roll":3
 }
insert_doc = y.insert_one(document)
insert = y.insert_one(document2)
print(insert_doc)

# %%
import pymongo
from pymongo.mongo_client import MongoClient
client = MongoClient("mongodb+srv://aryaamongodb:1t10jivwey6PTTsu@cluster0.mic7q.mongodb.net/")
x = client["practice"]
y = x["pr"]
read = y.find_one({"name":"aryaa", "roll":1})
read2 = y.find()
print(read)
print(read2)

# %%
import pymongo
from pymongo.mongo_client import MongoClient
client = MongoClient("mongodb+srv://aryaamongodb:1t10jivwey6PTTsu@cluster0.mic7q.mongodb.net/")
x = client["practice"]
y = x["pr"]
valu={"name":"vicky","roll":5}
valu2 ={"$set":{"name":"vi","roll":3}}
y.update_one(valu, valu2)

# %%
import pymongo
from pymongo.mongo_client import MongoClient
client = MongoClient("mongodb+srv://aryaamongodb:1t10jivwey6PTTsu@cluster0.mic7q.mongodb.net/")
x = client["practice"]
y = x["pr"]
delu = {"name":"vi"}
y.delete_one(delu)
print(delu)

# %%
import pymongo
from pymongo.mongo_client import MongoClient
client = MongoClient("mongodb+srv://aryaamongodb:1t10jivwey6PTTsu@cluster0.mic7q.mongodb.net/")

def find1(students):
    x = client["practice"]
    y = x["pr"]
    read = y.find_one(students)
    # read2 = y.find()
    return read

# %%
students ={"name": "vicky","roll":3}
output = find1(students)
print(output)

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)
users = {
    1: {'id': 1, 'name': 'John Doe', 'email': 'johndoe@example.com'},
    2: {'id': 2, 'name': 'Jane Smith', 'email': 'janesmith@example.com'}
}
@app.route('/users', methods=['POST'])
def create_user():
    data = request.get_json()
    user_id = len(users) + 1
    user = {'id': user_id, 'name': data['name'], 'email': data['email']}
    users[user_id] = user
    return user
if __name__ == "__main__":
    app.run()
